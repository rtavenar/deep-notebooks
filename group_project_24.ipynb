# %% [markdown]
# # Home assignment
#
# * Author: Romain Tavenard (@rtavenar)
# * License: CC-BY-NC-SA
#
# A home assignment from a course on Deep Learning at EDHEC.
#
# ## Problem statement
#
# The dataset we are interested in here is called "Wine Quality". It is described [in this page](https://archive.ics.uci.edu/dataset/186/wine+quality).
#
# You should load the data and train a prediction model for the target variable `quality`.
# You should compare several candidate neural network architectures, and make a decision about which is best for the task at hand.
# You should be explicit about the indicator(s) you base your decision on.
#
# Finally, as a bonus, you could try to evaluate whether it is better to:
# * train a single model for both white and red wine ;
# * train two different models, one for white wine and another one for red wine ;
# * train a model on white wine (respectively red wine) and fine-tune it on red wine (resp. white wine).
#
# ## Deadline
#
# Deadline for this home assignment is February 28th, 2024.
# You should use the link on moodle to hand in your assignment.
# A single ipynb file should be provided,
# with execution traces.
# This assignment is to be done **by groups of three, at most** and names of all students should be included in the file name.
#
# ## Data loading
#
# Code below loads the dataset as a pandas DataFrame. You should use `quality` as your target variable.

# %%
# %pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(name="Wine Quality") 
dataset = wine_quality.data.original
